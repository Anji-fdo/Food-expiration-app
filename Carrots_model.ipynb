# %%
# !unzip carrots_dataset.zip -d /content/datasets/carrots
# Out:
# Archive:  carrots_dataset.zip
#    creating: /content/datasets/carrots/carrots_dataset/1-2 days/
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/1.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (1).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (1).png
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (10).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (11).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (12).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (13).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (14).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (15).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (16).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (17).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (18).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (19).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (2).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (20).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (21).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (22).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (23).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (24).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (25).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (26).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (27).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (28).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (29).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (3).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (30).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (31).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (32).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (33).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (34).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (35).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (36).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (37).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (38).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (39).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (4).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (40).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (41).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (42).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (43).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (44).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (45).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (46).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (47).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (48).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (49).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (5).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (50).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (51).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (52).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (53).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (54).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (55).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (56).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (57).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (58).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (59).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (6).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (60).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (61).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (62).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (63).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (64).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (65).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (66).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (67).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (68).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (69).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (7).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (70).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (71).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (72).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (73).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (74).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (75).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (76).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (77).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (78).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (79).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (8).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (80).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (81).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (82).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (83).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (84).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (85).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (86).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (87).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (88).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (89).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (9).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (90).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (91).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (92).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (93).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (94).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (95).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (96).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (97).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/one to two (98).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (1).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (10).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (100).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (11).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (12).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (13).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (14).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (15).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (16).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (17).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (18).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (19).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (2).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (20).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (21).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (22).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (23).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (24).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (25).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (26).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (27).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (28).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (29).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (3).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (30).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (31).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (32).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (33).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (34).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (35).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (36).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (37).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (38).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (39).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (4).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (40).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (41).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (42).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (43).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (44).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (45).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (46).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (47).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (48).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (49).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (5).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (50).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (51).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (52).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (53).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (54).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (55).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (56).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (57).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (58).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (59).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (6).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (60).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (61).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (62).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (63).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (64).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (65).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (66).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (67).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (68).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (69).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (7).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (70).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (71).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (72).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (73).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (74).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (75).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (76).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (77).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (78).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (79).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (8).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (80).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (81).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (82).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (83).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (84).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (85).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (86).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (87).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (88).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (89).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (9).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (90).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (91).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (92).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (93).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (94).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (95).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (96).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (97).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (98).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/1-2 days/onedayy (99).jpg
#    creating: /content/datasets/carrots/carrots_dataset/3 days/
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/1.jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/100.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/15.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/3.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/6.jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/66.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/67.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/678.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/99.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (1).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (1).png
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (10).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (11).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (12).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (13).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (14).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (15).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (16).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (17).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (18).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (19).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (2).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (2).png
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (20).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (21).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (22).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (23).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (24).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (25).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (26).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (27).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (28).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (29).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (3).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (30).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (31).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (32).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (33).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (34).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (35).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (36).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (37).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (38).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (39).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (4).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (40).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (41).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (42).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (43).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (44).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (45).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (46).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (47).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (48).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (49).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (5).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (50).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (51).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (52).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (53).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (54).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (55).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (56).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (57).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (58).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (59).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (6).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (60).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (61).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (62).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (63).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (64).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (65).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (66).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (67).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (68).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (69).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (7).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (70).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (71).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (72).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (73).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (74).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (75).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (76).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (77).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (78).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (79).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (8).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (80).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (81).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (82).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (83).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (84).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (85).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (86).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (87).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (88).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (89).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/three days (9).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (1).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (10).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (100).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (11).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (12).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (13).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (14).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (15).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (16).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (17).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (18).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (19).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (2).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (20).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (21).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (22).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (23).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (24).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (25).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (26).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (27).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (28).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (29).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (3).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (30).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (31).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (32).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (33).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (34).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (35).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (36).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (37).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (38).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (39).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (4).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (40).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (41).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (42).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (43).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (44).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (45).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (46).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (47).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (48).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (49).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (5).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (50).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (51).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (52).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (53).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (54).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (55).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (56).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (57).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (58).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (59).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (6).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (60).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (61).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (62).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (63).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (64).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (65).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (66).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (67).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (68).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (69).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (7).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (70).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (71).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (72).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (73).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (74).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (75).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (76).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (77).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (78).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (79).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (8).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (80).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (81).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (82).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (83).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (84).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (85).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (86).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (87).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (88).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (89).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (9).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (90).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (91).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (92).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (93).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (94).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (95).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (96).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (97).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (98).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/3 days/threedays (99).jpg
#    creating: /content/datasets/carrots/carrots_dataset/4-5 days/
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/1.jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/100.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/16.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/2.jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/4.jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/567.jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/67.jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/7.jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/78.jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/91.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/92.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/93.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/94.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/95.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/96.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/97.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/98.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/99.PNG
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (1).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (10).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (100).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (11).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (12).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (13).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (14).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (15).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (16).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (17).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (18).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (19).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (2).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (20).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (21).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (22).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (23).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (24).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (25).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (26).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (27).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (28).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (29).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (3).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (30).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (31).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (32).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (33).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (34).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (35).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (36).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (37).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (38).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (39).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (4).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (40).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (41).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (42).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (43).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (44).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (45).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (46).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (47).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (48).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (49).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (5).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (50).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (51).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (52).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (53).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (54).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (55).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (56).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (57).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (58).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (59).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (6).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (60).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (61).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (62).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (63).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (64).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (65).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (66).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (67).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (68).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (69).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (7).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (70).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (71).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (72).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (73).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (74).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (75).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (76).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (77).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (78).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (79).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (8).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (80).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (81).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (82).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (83).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (84).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (85).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (86).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (87).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (88).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (89).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (9).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (90).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (91).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (92).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (93).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (94).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (95).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (96).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (97).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (98).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/five to four (99).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (1).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (1).png
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (10).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (11).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (12).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (13).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (14).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (15).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (16).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (17).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (18).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (19).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (2).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (2).png
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (20).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (21).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (22).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (23).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (24).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (25).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (26).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (27).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (28).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (29).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (3).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (3).png
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (30).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (31).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (32).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (33).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (34).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (35).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (36).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (37).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (38).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (39).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (4).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (40).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (41).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (42).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (43).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (44).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (45).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (46).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (47).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (48).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (49).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/4-5 days/four to five (5).jpg
# ...
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (12).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (13).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (14).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (15).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (16).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (17).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (18).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (19).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (2).jpeg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (2).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (20).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (21).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (22).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (23).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (24).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (25).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (26).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (27).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (28).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (29).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (3).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (30).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (31).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (32).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (33).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (34).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (35).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (36).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (37).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (38).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (39).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (4).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (40).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (41).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (42).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (43).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (44).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (45).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (46).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (47).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (48).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (49).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (5).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (50).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (51).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (52).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (53).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (54).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (55).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (56).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (57).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (58).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (59).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (6).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (60).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (61).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (62).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (63).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (64).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (65).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (66).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (67).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (68).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (69).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (7).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (70).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (71).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (72).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (73).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (74).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (75).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (76).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (77).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (78).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (79).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (8).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (80).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (81).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (82).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (83).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (84).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (85).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (86).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (87).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (88).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/six to seven (9).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (1).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (10).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (100).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (11).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (12).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (13).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (14).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (15).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (16).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (17).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (18).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (19).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (2).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (20).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (21).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (22).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (23).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (24).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (25).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (26).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (27).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (28).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (29).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (3).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (30).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (31).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (32).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (33).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (34).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (35).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (36).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (37).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (38).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (39).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (4).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (40).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (41).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (42).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (43).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (44).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (45).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (46).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (47).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (48).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (49).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (5).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (50).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (51).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (52).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (53).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (54).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (55).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (56).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (57).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (58).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (59).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (6).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (60).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (61).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (62).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (63).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (64).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (65).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (66).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (67).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (68).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (69).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (7).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (70).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (71).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (72).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (73).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (74).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (75).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (76).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (77).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (78).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (79).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (8).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (80).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (81).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (82).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (83).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (84).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (85).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (86).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (87).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (88).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (89).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (9).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (90).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (91).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (92).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (93).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (94).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (95).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (96).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (97).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (98).jpg
#   inflating: /content/datasets/carrots/carrots_dataset/6-7 days/sixseven (99).jpg

# %%
import os
import shutil

base_dir = '/content/datasets'
combined_dir = '/content/combined_dataset'
os.makedirs(combined_dir, exist_ok=True)

foods = [ 'carrots']

food_stages = {

    'carrots': ['1-2 days', '3 days', '4-5 days', '6-7 days'],

}

for food in foods:
    food_path = os.path.join(base_dir, food)
    if os.path.exists(food_path):
        nested_folder = None
        for item in os.listdir(food_path):
            full_path = os.path.join(food_path, item)
            if os.path.isdir(full_path) and item.lower() == f"{food}_dataset".lower():
                nested_folder = full_path
                break
        if nested_folder:
            actual_stages = [d for d in os.listdir(nested_folder) if os.path.isdir(os.path.join(nested_folder, d))]
        else:
            actual_stages = [d for d in os.listdir(food_path) if os.path.isdir(os.path.join(food_path, d))]
        print(f"Checking {food}: Nested folder? {nested_folder}, Expected stages: {food_stages[food]}, Actual stages: {actual_stages}")
        for stage in food_stages[food]:
            src = os.path.join(nested_folder if nested_folder else food_path, stage)
            if os.path.exists(src):
                dst_class = f"{food}_{stage}"
                dst = os.path.join(combined_dir, dst_class)
                os.makedirs(dst, exist_ok=True)
                for img in os.listdir(src):
                    if os.path.isfile(os.path.join(src, img)):
                        shutil.copy(os.path.join(src, img), os.path.join(dst, img))
            else:
                print(f"Warning: {src} not found for {food}")

print("Combined dataset classes:", os.listdir(combined_dir))
# Out:
# Checking carrots: Nested folder? /content/datasets/carrots/carrots_dataset, Expected stages: ['1-2 days', '3 days', '4-5 days', '6-7 days'], Actual stages: ['1-2 days', '3 days', '6-7 days', '4-5 days']
# Combined dataset classes: ['carrots_3 days', 'carrots_1-2 days', 'carrots_6-7 days', 'carrots_4-5 days']

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import class_weight
import random
import os

# Custom Cutout augmentation
def cutout(image):
    if random.random() < 0.5:  # Apply Cutout with 50% probability
        h, w = image.shape[:2]
        cutout_size = random.randint(20, 70)  # Increased size range for carrots
        x = random.randint(0, w - cutout_size)
        y = random.randint(0, h - cutout_size)
        image[y:y+cutout_size, x:x+cutout_size, :] = 0
    return image

# Combined preprocessing function for MobileNetV2 and Cutout
def preprocess_with_cutout(x):
    x = tf.keras.applications.mobilenet_v2.preprocess_input(x)
    x = cutout(x)
    return x

# Step 1: Set up data generators with enhanced augmentation for carrot dataset
datagen_aug = ImageDataGenerator(
    preprocessing_function=preprocess_with_cutout,
    validation_split=0.2,
    rotation_range=80,  # Increased for more diversity
    width_shift_range=0.5,
    height_shift_range=0.5,
    shear_range=0.5,
    zoom_range=[0.2, 1.8],  # Wider zoom range
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest',
    brightness_range=[0.4, 1.6],
    channel_shift_range=40.0  # Increased for stronger color jittering
)

datagen_no_aug = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
    validation_split=0.2
)

# Ensure dataset directory exists
data_dir = '/content/combined_dataset'
if not os.path.exists(data_dir):
    raise FileNotFoundError(f"Dataset directory {data_dir} not found. Please update the path or ensure the dataset exists.")

# Check dataset structure
subdirs = [d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
print(f"Found subdirectories: {subdirs}")
if len(subdirs) != 4:
    print(f"Warning: Expected 4 subdirectories, found {len(subdirs)}. Please check dataset structure.")

# Count images in each subdirectory
for subdir in subdirs:
    subdir_path = os.path.join(data_dir, subdir)
    image_files = [f for f in os.listdir(subdir_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    print(f"Subdirectory {subdir}: {len(image_files)} images")

train_generator = datagen_aug.flow_from_directory(
    data_dir,
    target_size=(256, 256),  # Increased resolution
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

val_generator = datagen_no_aug.flow_from_directory(
    data_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Verify class indices and check for balance
print("Class indices:", train_generator.class_indices)
print("Number of classes:", len(train_generator.class_indices))
class_counts = np.bincount(train_generator.classes)
print("Class distribution:", dict(zip(train_generator.class_indices.keys(), class_counts)))

# Compute class weights for potential imbalance
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights_dict = dict(enumerate(class_weights))

# Step 2: Build MobileNetV2 model optimized for 4-class carrot classification
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(256, 256, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.00002))(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)
x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.00002))(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)
predictions = Dense(4, activation='softmax')(x)

new_model = Model(inputs=base_model.input, outputs=predictions)

# Freeze base layers initially
for layer in base_model.layers:
    layer.trainable = False

new_model.compile(optimizer=AdamW(learning_rate=0.001, weight_decay=0.0001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# Callbacks
early_stop = EarlyStopping(monitor='val_accuracy', patience=25, restore_best_weights=True, mode='max')
lr_reduce = ReduceLROnPlateau(monitor='val_accuracy', factor=0.02, patience=6, min_lr=1e-8, mode='max')
checkpoint = ModelCheckpoint('best_mobilenet_carrot_model.keras', monitor='val_accuracy', save_best_only=True, mode='max')

# Train initial phase
history = new_model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,  # Increased for better convergence
    validation_data=val_generator,
    validation_steps=len(val_generator),
    callbacks=[early_stop, lr_reduce, checkpoint],
    class_weight=class_weights_dict
)

# Fine-tune more layers (MobileNetV2 has ~154 layers)
for layer in base_model.layers[-120:]:
    layer.trainable = True

new_model.compile(optimizer=AdamW(learning_rate=0.000005, weight_decay=0.00001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# Fine-tune
history_fine = new_model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,  # Increased for better convergence
    validation_data=val_generator,
    validation_steps=len(val_generator),
    callbacks=[early_stop, lr_reduce, checkpoint],
    class_weight=class_weights_dict
)

# Evaluate
val_loss_new, val_acc_new = new_model.evaluate(val_generator)
print(f"Carrot Model Validation Accuracy: {val_acc_new * 100:.2f}%")



# Save the final model
new_model.save('improved_mobilenet_carrot_model.keras')

# Plot training and validation accuracy
train_accuracy = history.history['accuracy'] + history_fine.history['accuracy']
val_accuracy = history.history['val_accuracy'] + history_fine.history['val_accuracy']
epochs = list(range(1, len(train_accuracy) + 1))

plt.figure(figsize=(10, 6))
plt.plot(epochs, [acc * 100 for acc in train_accuracy], label='Training Accuracy', color='#1f77b4')
plt.plot(epochs, [acc * 100 for acc in val_accuracy], label='Validation Accuracy', color='#ff7f0e')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training and Validation Accuracy Over Epochs (Carrot Model)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Found subdirectories: ['carrots_3 days', 'carrots_1-2 days', 'carrots_6-7 days', 'carrots_4-5 days']
# Subdirectory carrots_3 days: 200 images
# Subdirectory carrots_1-2 days: 200 images
# Subdirectory carrots_6-7 days: 200 images
# Subdirectory carrots_4-5 days: 200 images
# Found 640 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Class indices: {'carrots_1-2 days': 0, 'carrots_3 days': 1, 'carrots_4-5 days': 2, 'carrots_6-7 days': 3}
# Number of classes: 4
# Class distribution: {'carrots_1-2 days': np.int64(160), 'carrots_3 days': np.int64(160), 'carrots_4-5 days': np.int64(160), 'carrots_6-7 days': np.int64(160)}
# /tmp/ipython-input-4282428977.py:101: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(256, 256, 3))
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.5600 - loss: 1.4136 - val_accuracy: 0.5562 - val_loss: 1.3573 - learning_rate: 0.0010
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.7461 - loss: 1.0034 - val_accuracy: 0.5750 - val_loss: 1.3458 - learning_rate: 0.0010
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.7428 - loss: 0.8581 - val_accuracy: 0.6062 - val_loss: 1.2716 - learning_rate: 0.0010
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.7576 - loss: 0.7938 - val_accuracy: 0.5500 - val_loss: 1.8174 - learning_rate: 0.0010
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.7911 - loss: 0.6595 - val_accuracy: 0.6562 - val_loss: 1.2521 - learning_rate: 0.0010
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.8021 - loss: 0.6755 - val_accuracy: 0.6187 - val_loss: 1.6160 - learning_rate: 0.0010
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.7859 - loss: 0.6860 - val_accuracy: 0.6687 - val_loss: 2.0112 - learning_rate: 0.0010
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.8049 - loss: 0.5977 - val_accuracy: 0.6375 - val_loss: 1.2500 - learning_rate: 0.0010
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.7764 - loss: 0.6182 - val_accuracy: 0.6500 - val_loss: 1.3648 - learning_rate: 0.0010
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.7961 - loss: 0.5830 - val_accuracy: 0.6250 - val_loss: 1.4361 - learning_rate: 0.0010
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.8072 - loss: 0.5883 - val_accuracy: 0.6750 - val_loss: 1.3561 - learning_rate: 0.0010
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.8152 - loss: 0.5607 - val_accuracy: 0.6313 - val_loss: 1.5191 - learning_rate: 0.0010
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.7959 - loss: 0.5539 - val_accuracy: 0.6687 - val_loss: 1.5640 - learning_rate: 0.0010
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.8092 - loss: 0.6032 - val_accuracy: 0.6625 - val_loss: 1.4893 - learning_rate: 0.0010
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.8126 - loss: 0.5976 - val_accuracy: 0.6438 - val_loss: 1.6562 - learning_rate: 0.0010
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.7758 - loss: 0.6031 - val_accuracy: 0.6687 - val_loss: 1.5179 - learning_rate: 0.0010
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.8055 - loss: 0.5142 - val_accuracy: 0.6750 - val_loss: 1.7368 - learning_rate: 0.0010
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.8546 - loss: 0.4612 - val_accuracy: 0.6750 - val_loss: 1.7138 - learning_rate: 2.0000e-05
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 85s 3s/step - accuracy: 0.8120 - loss: 0.5163 - val_accuracy: 0.6750 - val_loss: 1.6785 - learning_rate: 2.0000e-05
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.8279 - loss: 0.5020 - val_accuracy: 0.6812 - val_loss: 1.6387 - learning_rate: 2.0000e-05
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.8072 - loss: 0.5432 - val_accuracy: 0.6812 - val_loss: 1.6192 - learning_rate: 2.0000e-05
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.8499 - loss: 0.4255 - val_accuracy: 0.6812 - val_loss: 1.5931 - learning_rate: 2.0000e-05
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.8415 - loss: 0.4603 - val_accuracy: 0.6750 - val_loss: 1.5796 - learning_rate: 2.0000e-05
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.8409 - loss: 0.4571 - val_accuracy: 0.6812 - val_loss: 1.5649 - learning_rate: 2.0000e-05
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.8506 - loss: 0.4675 - val_accuracy: 0.6812 - val_loss: 1.5614 - learning_rate: 2.0000e-05
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.8296 - loss: 0.5306 - val_accuracy: 0.6875 - val_loss: 1.5667 - learning_rate: 2.0000e-05
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.8468 - loss: 0.4179 - val_accuracy: 0.6875 - val_loss: 1.5683 - learning_rate: 2.0000e-05
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.8421 - loss: 0.4785 - val_accuracy: 0.6938 - val_loss: 1.5675 - learning_rate: 2.0000e-05
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.8390 - loss: 0.4772 - val_accuracy: 0.6938 - val_loss: 1.5599 - learning_rate: 2.0000e-05
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.8589 - loss: 0.4652 - val_accuracy: 0.6875 - val_loss: 1.5583 - learning_rate: 2.0000e-05
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.8576 - loss: 0.4277 - val_accuracy: 0.6938 - val_loss: 1.5462 - learning_rate: 2.0000e-05
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.8502 - loss: 0.4428 - val_accuracy: 0.7000 - val_loss: 1.5356 - learning_rate: 2.0000e-05
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.8265 - loss: 0.4567 - val_accuracy: 0.7000 - val_loss: 1.5256 - learning_rate: 2.0000e-05
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 85s 3s/step - accuracy: 0.8239 - loss: 0.5181 - val_accuracy: 0.7000 - val_loss: 1.5317 - learning_rate: 2.0000e-05
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - accuracy: 0.8269 - loss: 0.4789 - val_accuracy: 0.7000 - val_loss: 1.5415 - learning_rate: 2.0000e-05
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.8770 - loss: 0.3717 - val_accuracy: 0.6938 - val_loss: 1.5349 - learning_rate: 2.0000e-05
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.8554 - loss: 0.4386 - val_accuracy: 0.6938 - val_loss: 1.5385 - learning_rate: 2.0000e-05
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.8801 - loss: 0.4088 - val_accuracy: 0.7000 - val_loss: 1.5333 - learning_rate: 2.0000e-05
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.8602 - loss: 0.3996 - val_accuracy: 0.7063 - val_loss: 1.5312 - learning_rate: 4.0000e-07
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.8611 - loss: 0.3933 - val_accuracy: 0.7000 - val_loss: 1.5357 - learning_rate: 4.0000e-07
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - accuracy: 0.8303 - loss: 0.4685 - val_accuracy: 0.7000 - val_loss: 1.5399 - learning_rate: 4.0000e-07
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.8316 - loss: 0.5001 - val_accuracy: 0.7000 - val_loss: 1.5356 - learning_rate: 4.0000e-07
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.8456 - loss: 0.4386 - val_accuracy: 0.6938 - val_loss: 1.5315 - learning_rate: 4.0000e-07
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.8747 - loss: 0.3732 - val_accuracy: 0.7000 - val_loss: 1.5362 - learning_rate: 4.0000e-07
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.8233 - loss: 0.4750 - val_accuracy: 0.7000 - val_loss: 1.5328 - learning_rate: 4.0000e-07
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.8214 - loss: 0.5422 - val_accuracy: 0.6938 - val_loss: 1.5257 - learning_rate: 1.0000e-08
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.8379 - loss: 0.4697 - val_accuracy: 0.7000 - val_loss: 1.5336 - learning_rate: 1.0000e-08
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.8790 - loss: 0.3889 - val_accuracy: 0.6938 - val_loss: 1.5247 - learning_rate: 1.0000e-08
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.8433 - loss: 0.4138 - val_accuracy: 0.7000 - val_loss: 1.5324 - learning_rate: 1.0000e-08
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.8349 - loss: 0.5145 - val_accuracy: 0.7000 - val_loss: 1.5240 - learning_rate: 1.0000e-08
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 132s 5s/step - accuracy: 0.6563 - loss: 1.1027 - val_accuracy: 0.6812 - val_loss: 1.6344 - learning_rate: 5.0000e-06
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 98s 5s/step - accuracy: 0.6855 - loss: 1.0925 - val_accuracy: 0.6812 - val_loss: 1.7300 - learning_rate: 5.0000e-06
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 142s 5s/step - accuracy: 0.7373 - loss: 0.8511 - val_accuracy: 0.6750 - val_loss: 1.8404 - learning_rate: 5.0000e-06
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.7140 - loss: 0.8421 - val_accuracy: 0.6687 - val_loss: 1.9339 - learning_rate: 5.0000e-06
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 97s 5s/step - accuracy: 0.7703 - loss: 0.7442 - val_accuracy: 0.6687 - val_loss: 2.0107 - learning_rate: 5.0000e-06
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 144s 5s/step - accuracy: 0.7387 - loss: 0.8138 - val_accuracy: 0.6687 - val_loss: 2.0820 - learning_rate: 5.0000e-06
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 98s 5s/step - accuracy: 0.7333 - loss: 0.7182 - val_accuracy: 0.6625 - val_loss: 2.1590 - learning_rate: 5.0000e-06
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 100s 5s/step - accuracy: 0.7554 - loss: 0.7476 - val_accuracy: 0.6625 - val_loss: 2.1908 - learning_rate: 1.0000e-07
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 141s 5s/step - accuracy: 0.7193 - loss: 0.8003 - val_accuracy: 0.6562 - val_loss: 2.2265 - learning_rate: 1.0000e-07
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 142s 5s/step - accuracy: 0.7170 - loss: 0.8741 - val_accuracy: 0.6625 - val_loss: 2.2538 - learning_rate: 1.0000e-07
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 98s 5s/step - accuracy: 0.7959 - loss: 0.6790 - val_accuracy: 0.6625 - val_loss: 2.2777 - learning_rate: 1.0000e-07
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.7605 - loss: 0.8177 - val_accuracy: 0.6687 - val_loss: 2.2960 - learning_rate: 1.0000e-07
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 141s 5s/step - accuracy: 0.7158 - loss: 0.8516 - val_accuracy: 0.6687 - val_loss: 2.3080 - learning_rate: 1.0000e-07
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 99s 5s/step - accuracy: 0.7554 - loss: 0.7356 - val_accuracy: 0.6625 - val_loss: 2.3217 - learning_rate: 1.0000e-08
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 97s 5s/step - accuracy: 0.7853 - loss: 0.6527 - val_accuracy: 0.6625 - val_loss: 2.3298 - learning_rate: 1.0000e-08
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 99s 5s/step - accuracy: 0.7600 - loss: 0.7121 - val_accuracy: 0.6438 - val_loss: 2.3360 - learning_rate: 1.0000e-08
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 141s 5s/step - accuracy: 0.7304 - loss: 0.7060 - val_accuracy: 0.6500 - val_loss: 2.3490 - learning_rate: 1.0000e-08
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 98s 5s/step - accuracy: 0.7345 - loss: 0.8866 - val_accuracy: 0.6625 - val_loss: 2.3443 - learning_rate: 1.0000e-08
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.7830 - loss: 0.6555 - val_accuracy: 0.6625 - val_loss: 2.3391 - learning_rate: 1.0000e-08
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 144s 5s/step - accuracy: 0.7353 - loss: 0.7240 - val_accuracy: 0.6687 - val_loss: 2.3317 - learning_rate: 1.0000e-08
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 98s 5s/step - accuracy: 0.7901 - loss: 0.6337 - val_accuracy: 0.6625 - val_loss: 2.3367 - learning_rate: 1.0000e-08
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 142s 5s/step - accuracy: 0.7423 - loss: 0.7591 - val_accuracy: 0.6625 - val_loss: 2.3395 - learning_rate: 1.0000e-08
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 96s 5s/step - accuracy: 0.7357 - loss: 0.8276 - val_accuracy: 0.6625 - val_loss: 2.3342 - learning_rate: 1.0000e-08
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 97s 5s/step - accuracy: 0.7241 - loss: 0.8203 - val_accuracy: 0.6625 - val_loss: 2.3252 - learning_rate: 1.0000e-08
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 98s 5s/step - accuracy: 0.7368 - loss: 0.7710 - val_accuracy: 0.6625 - val_loss: 2.3256 - learning_rate: 1.0000e-08
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 98s 5s/step - accuracy: 0.7713 - loss: 0.6835 - val_accuracy: 0.6625 - val_loss: 2.3323 - learning_rate: 1.0000e-08
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.5496 - loss: 2.6593
# Carrot Model Validation Accuracy: 68.12%

# %%
# Enhanced Test-Time Augmentation (TTA)
def tta_evaluate(model, num_augs=50):
    tta_datagen = ImageDataGenerator(
        preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
        rotation_range=50,
        width_shift_range=0.4,
        height_shift_range=0.4,
        shear_range=0.4,
        zoom_range=0.4,
        horizontal_flip=True,
        fill_mode='nearest',
        validation_split=0.2
    )
    preds = []
    y_true = val_generator.classes
    for i in range(num_augs):
        tta_gen = tta_datagen.flow_from_directory(
            data_dir,
            target_size=(256, 256),
            batch_size=32,
            class_mode='categorical',
            subset='validation',
            shuffle=False,
            seed=42 + i
        )
        batch_preds = model.predict(tta_gen, steps=len(tta_gen), verbose=0)
        preds.append(batch_preds)
    avg_preds = np.mean(preds, axis=0)
    acc = np.mean(np.argmax(avg_preds, axis=1) == y_true)
    return acc * 100

tta_acc_new = tta_evaluate(new_model)
print(f"Carrot Model TTA Validation Accuracy: {tta_acc_new:.2f}%")

# Save the final model
new_model.save('improved_mobilenet_carrots_model(2).keras')
# Out:
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Found 160 images belonging to 4 classes.
# Carrot Model TTA Validation Accuracy: 71.25%

# %%
# Plot training and validation accuracy
train_accuracy = history.history['accuracy'] + history_fine.history['accuracy']
val_accuracy = history.history['val_accuracy'] + history_fine.history['val_accuracy']
epochs = list(range(1, len(train_accuracy) + 1))

plt.figure(figsize=(10, 6))
plt.plot(epochs, [acc * 100 for acc in train_accuracy], label='Training Accuracy', color='#1f77b4')
plt.plot(epochs, [acc * 100 for acc in val_accuracy], label='Validation Accuracy', color='#ff7f0e')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training and Validation Accuracy Over Epochs (Carrot Model)')
plt.legend()
plt.grid(True)
plt.show()
