# %%
# !unzip apple_dataset.zip -d /content/datasets/apple
# Out:
# Archive:  apple_dataset.zip
#    creating: /content/datasets/apple/apple_dataset/10-12 days/
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/1.PNG
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/11.jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/12.jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/13.jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/14.jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/15.jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/17.jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/18.jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/19.jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/2.PNG
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/3.PNG
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/4.PNG
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/5.PNG
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/6.PNG
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/7.PNG
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/8.PNG
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (1).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (10).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (100).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (11).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (12).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (13).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (14).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (15).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (16).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (17).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (18).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (19).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (2).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (20).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (21).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (22).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (23).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (24).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (25).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (26).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (27).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (28).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (29).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (3).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (30).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (31).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (32).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (33).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (34).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (35).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (36).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (37).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (38).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (39).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (4).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (40).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (41).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (42).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (43).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (44).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (45).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (46).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (47).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (48).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (49).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (5).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (50).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (51).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (52).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (53).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (54).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (55).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (56).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (57).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (58).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (59).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (6).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (60).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (61).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (62).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (63).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (64).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (65).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (66).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (67).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (68).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (69).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (7).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (70).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (71).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (72).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (73).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (74).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (75).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (76).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (77).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (78).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (79).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (8).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (80).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (81).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (82).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (83).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (84).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (85).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (86).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (87).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (88).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (89).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (9).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (90).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (91).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (92).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (93).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (94).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (95).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (96).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (97).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (98).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_l3 (99).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (1).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (13).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (14).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (15).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (16).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (17).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (18).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (19).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (2).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (20).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (21).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (24).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (28).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (29).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (3).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (30).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (31).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (32).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (33).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (34).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (35).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (36).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (37).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (38).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (39).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (4).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (40).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (41).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (42).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (43).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (44).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (45).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (46).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (47).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (48).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (49).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (5).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (50).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (51).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (52).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (53).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (54).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (55).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (56).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (57).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (58).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (59).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (6).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (60).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (61).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (62).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (63).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (64).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (65).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (66).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (67).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (68).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (69).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (7).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (70).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (71).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (72).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (73).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (74).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (75).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (76).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (77).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (78).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (79).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (80).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (81).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (82).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (83).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (84).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (85).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (86).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (87).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (88).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (89).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (90).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (91).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level2 (92).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level22 (1).jpg
#   inflating: /content/datasets/apple/apple_dataset/10-12 days/apple_level22 (2).jpg
#    creating: /content/datasets/apple/apple_dataset/1-3 days/
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (1).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (10).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (11).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (112).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (113).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (114).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (115).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (116).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (117).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (118).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (119).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (12).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (120).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (121).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (122).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (123).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (124).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (125).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (126).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (127).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (128).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (129).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (13).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (130).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (131).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (14).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (15).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (16).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (17).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (18).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (19).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (2).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (20).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (21).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (22).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (23).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (24).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (25).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (26).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (27).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (28).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (29).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (3).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (30).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (31).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (32).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (33).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (34).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (35).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (36).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (37).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (38).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (39).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (4).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (40).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (41).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (42).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (43).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (44).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (45).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (46).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (47).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (48).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (49).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (5).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (50).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (51).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (52).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (53).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (54).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (55).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (56).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (57).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (58).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (59).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (6).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (60).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (61).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (62).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (63).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (64).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (65).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (66).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (67).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (68).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (69).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (7).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (70).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (71).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (72).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (73).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (74).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (75).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (76).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (77).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (78).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (79).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (8).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (80).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (81).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (82).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (83).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (84).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (9).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (91).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (92).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (93).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (94).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (95).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/Apple_l6 (96).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (1).png
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (12).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (15).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (16).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (18).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (19).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (2).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (21).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (23).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (24).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (25).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (26).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (27).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (28).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (29).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (3).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (3).png
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (30).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (31).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (32).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (33).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (34).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (35).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (36).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (37).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (38).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (4).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (4).png
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (5).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (6).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (8).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (81).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (82).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (83).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (84).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (85).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (86).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (87).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (88).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (89).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (9).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (90).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/apple_level5 (91).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/img.jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one to three (1).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one to three (10).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one to three (11).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one to three (2).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one to three (3).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one to three (4).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one to three (5).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one to three (6).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one to three (7).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one to three (8).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one to three (9).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one.PNG
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one_2.PNG
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/one_3.PNG
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (1).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (1).PNG
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (10).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (11).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (12).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (13).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (14).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (15).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (16).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (17).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (18).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (19).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (2).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (20).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (21).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (22).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (23).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (24).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (25).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (26).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (27).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (28).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (29).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (3).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (30).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (31).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (4).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (5).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (6).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (7).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (8).jpg
#   inflating: /content/datasets/apple/apple_dataset/1-3 days/ONETOTHREE (9).jpg
#    creating: /content/datasets/apple/apple_dataset/13-15 days/
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/02.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/1.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/12.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/13.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/15.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/17.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/18.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/2.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/3.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/4.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/5.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/7.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/9.jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (1).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (10).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (100).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (11).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (12).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (13).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (14).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (15).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (16).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (17).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (18).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (19).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (2).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (20).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (21).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (22).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (23).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (24).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (25).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (26).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (27).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (28).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (29).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (3).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (30).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (31).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (32).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (33).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (34).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (35).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (36).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (37).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (38).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (39).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (4).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (40).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (41).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (42).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (43).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (44).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (45).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (46).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (47).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (48).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (49).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (5).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (50).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (51).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (52).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (53).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (54).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (55).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (56).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (57).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (58).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (59).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (6).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (60).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (61).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (62).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (63).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (64).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (65).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (66).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (67).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (68).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (69).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (7).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (70).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (71).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (72).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (73).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (74).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (75).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (76).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (77).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (78).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (79).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (8).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (80).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (81).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (82).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (83).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (84).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (85).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (86).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (87).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (88).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (89).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (9).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (90).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (91).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (92).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (93).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (94).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (95).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (96).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (97).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (98).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_4 (99).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (1).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (1).png
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (10).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (101).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (102).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (11).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (12).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (13).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (14).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (15).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (17).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (18).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (19).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (2).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (20).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (21).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (22).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (23).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (25).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (26).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (28).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (29).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (3).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (31).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (32).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (33).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (36).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (37).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (40).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (41).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (42).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (44).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (45).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (46).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (47).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (48).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (49).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (5).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (51).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (52).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (53).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (54).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (55).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (56).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (57).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (58).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (59).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (6).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (60).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (61).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (62).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (63).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (64).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (65).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (66).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (67).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (68).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (69).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (7).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (70).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (71).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (72).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (74).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (75).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (76).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (77).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (78).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (79).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (8).jpg
#   inflating: /content/datasets/apple/apple_dataset/13-15 days/apple_level1 (81).jpg
# ...
#   inflating: /content/datasets/apple/apple_dataset/4-6 days/two_2.PNG
#   inflating: /content/datasets/apple/apple_dataset/4-6 days/two_3.PNG
#    creating: /content/datasets/apple/apple_dataset/7-9 days/
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/135_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/136_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/137_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/138_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/139_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/140_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/141_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/142_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/143_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/144_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/145_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/146_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/147_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/148_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/149_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/150_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/151_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/152_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/153_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/154_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/155_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/156_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/157_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/158_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/159_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/160_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/161_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/162_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/163_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/164_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/165_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/166_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/167_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/168_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/169_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/170_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/171_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/183_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/184_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/185_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/186_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/187_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/188_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/189_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/190_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/191_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/192_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/193_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/194_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/195_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/196_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/197_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/198_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/199_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/2.PNG
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/200_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/201_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/202_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/203_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/204_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/205_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/4.PNG
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/5.PNG
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/6.PNG
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/7.PNG
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (1).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (1).png
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (10).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (11).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (12).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (13).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (14).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (15).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (16).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (17).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (18).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (19).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (2).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (2).png
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (20).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (21).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (22).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (23).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (24).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (25).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (26).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (27).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (28).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (29).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (3).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (30).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (31).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (32).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (33).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (34).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (35).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (36).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (37).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (38).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (39).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (4).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (40).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (41).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (42).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (43).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (44).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (45).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (46).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (47).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (48).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (49).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (5).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (50).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (51).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (52).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (53).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (54).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (55).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (56).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (57).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (58).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (59).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (6).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (60).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (61).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (62).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (63).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (64).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (65).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (66).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (67).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (68).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (69).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (7).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (70).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (71).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (72).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (73).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (74).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (75).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (76).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (77).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (78).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (79).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (8).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (80).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (81).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (82).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (83).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (84).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (85).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (86).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (87).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (88).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (89).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (9).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (90).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (91).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/apple_level3 (92).jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_235_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_236_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_237_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_238_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_239_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_240_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_241_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_242_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_243_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_244_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_245_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_246_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_247_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_248_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_249_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_250_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_251_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_252_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_253_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_254_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_255_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_256_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_257_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_258_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_259_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_260_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_261_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_262_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_263_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_264_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_265_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_266_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_267_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_268_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_269_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_270_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_271_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_303_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_304_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/r_305_100.jpg
#   inflating: /content/datasets/apple/apple_dataset/7-9 days/three.PNG

# %%
import os
import shutil

base_dir = '/content/datasets'
combined_dir = '/content/combined_dataset'
os.makedirs(combined_dir, exist_ok=True)

foods = ['apple']

food_stages = {
    'apple': ['1-3 days', '4-6 days', '7-9 days', '10-12 days', '13-15 days'],

}

for food in foods:
    food_path = os.path.join(base_dir, food)
    if os.path.exists(food_path):
        nested_folder = None
        for item in os.listdir(food_path):
            full_path = os.path.join(food_path, item)
            if os.path.isdir(full_path) and item.lower() == f"{food}_dataset".lower():
                nested_folder = full_path
                break
        if nested_folder:
            actual_stages = [d for d in os.listdir(nested_folder) if os.path.isdir(os.path.join(nested_folder, d))]
        else:
            actual_stages = [d for d in os.listdir(food_path) if os.path.isdir(os.path.join(food_path, d))]
        print(f"Checking {food}: Nested folder? {nested_folder}, Expected stages: {food_stages[food]}, Actual stages: {actual_stages}")
        for stage in food_stages[food]:
            src = os.path.join(nested_folder if nested_folder else food_path, stage)
            if os.path.exists(src):
                dst_class = f"{food}_{stage}"
                dst = os.path.join(combined_dir, dst_class)
                os.makedirs(dst, exist_ok=True)
                for img in os.listdir(src):
                    if os.path.isfile(os.path.join(src, img)):
                        shutil.copy(os.path.join(src, img), os.path.join(dst, img))
            else:
                print(f"Warning: {src} not found for {food}")

print("Combined dataset classes:", os.listdir(combined_dir))
# Out:
# Checking apple: Nested folder? /content/datasets/apple/apple_dataset, Expected stages: ['1-3 days', '4-6 days', '7-9 days', '10-12 days', '13-15 days'], Actual stages: ['10-12 days', '13-15 days', '7-9 days', '1-3 days', '4-6 days']
# Combined dataset classes: ['apple_10-12 days', 'apple_7-9 days', 'apple_1-3 days', 'apple_4-6 days', 'apple_13-15 days']

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import class_weight
import random
import os

# Custom Cutout augmentation
def cutout(image):
    if random.random() < 0.6:  # Increased probability to 60%
        h, w = image.shape[:2]
        cutout_size = random.randint(20, 70)
        x = random.randint(0, w - cutout_size)
        y = random.randint(0, h - cutout_size)
        image[y:y+cutout_size, x:x+cutout_size, :] = 0
    return image

# Combined preprocessing function for EfficientNetB1 and Cutout
def preprocess_with_cutout(x):
    x = tf.keras.applications.efficientnet.preprocess_input(x)
    x = cutout(x)
    return x

# Step 1: Set up data generators with refined augmentation for apple dataset
datagen_aug = ImageDataGenerator(
    preprocessing_function=preprocess_with_cutout,
    validation_split=0.2,
    rotation_range=60,  # Reduced to avoid excessive distortion
    width_shift_range=0.5,
    height_shift_range=0.5,
    shear_range=0.5,
    zoom_range=[0.2, 1.8],
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest',
    brightness_range=[0.3, 1.7],
    channel_shift_range=40.0
)

datagen_no_aug = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    validation_split=0.2
)

# Ensure dataset directory exists
data_dir = '/content/combined_dataset'
if not os.path.exists(data_dir):
    raise FileNotFoundError(f"Dataset directory {data_dir} not found. Please update the path or ensure the dataset exists.")

# Check dataset structure
subdirs = [d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
print(f"Found subdirectories: {subdirs}")
if len(subdirs) != 5:
    print(f"Warning: Expected 5 subdirectories, found {len(subdirs)}. Please check dataset structure.")

# Count images in each subdirectory
for subdir in subdirs:
    subdir_path = os.path.join(data_dir, subdir)
    image_files = [f for f in os.listdir(subdir_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    print(f"Subdirectory {subdir}: {len(image_files)} images")

train_generator = datagen_aug.flow_from_directory(
    data_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

val_generator = datagen_no_aug.flow_from_directory(
    data_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Verify class indices and check for balance
print("Class indices:", train_generator.class_indices)
print("Number of classes:", len(train_generator.class_indices))
class_counts = np.bincount(train_generator.classes)
print("Class distribution:", dict(zip(train_generator.class_indices.keys(), class_counts)))

# Compute class weights for potential imbalance
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights_dict = dict(enumerate(class_weights))

# Step 2: Build EfficientNetB1 model optimized for 5-class apple classification
base_model = EfficientNetB1(weights='imagenet', include_top=False, input_shape=(256, 256, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.00005))(x)
x = BatchNormalization()(x)
x = Dropout(0.15)(x)
x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.00005))(x)
x = BatchNormalization()(x)
x = Dropout(0.15)(x)
predictions = Dense(5, activation='softmax')(x)

new_model = Model(inputs=base_model.input, outputs=predictions)

# Freeze base layers initially
for layer in base_model.layers:
    layer.trainable = False

new_model.compile(optimizer=AdamW(learning_rate=0.0003, weight_decay=0.0001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# Callbacks
early_stop = EarlyStopping(monitor='val_accuracy', patience=30, restore_best_weights=True, mode='max')
lr_reduce = ReduceLROnPlateau(monitor='val_accuracy', factor=0.02, patience=6, min_lr=1e-8, mode='max')
checkpoint = ModelCheckpoint('best_efficientnet_apple_model.keras', monitor='val_accuracy', save_best_only=True, mode='max')

# Train initial phase
history = new_model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=150,
    validation_data=val_generator,
    validation_steps=len(val_generator),
    callbacks=[early_stop, lr_reduce, checkpoint],
    class_weight=class_weights_dict
)

# Fine-tune fewer layers for stability (EfficientNetB1 has ~314 layers)
for layer in base_model.layers[-100:]:
    layer.trainable = True

new_model.compile(optimizer=AdamW(learning_rate=0.0000005, weight_decay=0.00001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# Fine-tune
history_fine = new_model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=150,
    validation_data=val_generator,
    validation_steps=len(val_generator),
    callbacks=[early_stop, lr_reduce, checkpoint],
    class_weight=class_weights_dict
)

# Evaluate
val_loss_new, val_acc_new = new_model.evaluate(val_generator)
print(f"Apple Model Validation Accuracy: {val_acc_new * 100:.2f}%")

# Enhanced Test-Time Augmentation (TTA)
def tta_evaluate(model, num_augs=50):
    tta_datagen = ImageDataGenerator(
        preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
        rotation_range=50,
        width_shift_range=0.4,
        height_shift_range=0.4,
        shear_range=0.4,
        zoom_range=0.4,
        horizontal_flip=True,
        fill_mode='nearest',
        validation_split=0.2
    )
    preds = []
    y_true = val_generator.classes
    for i in range(num_augs):
        tta_gen = tta_datagen.flow_from_directory(
            data_dir,
            target_size=(256, 256),
            batch_size=32,
            class_mode='categorical',
            subset='validation',
            shuffle=False,
            seed=42 + i
        )
        batch_preds = model.predict(tta_gen, steps=len(tta_gen), verbose=0)
        preds.append(batch_preds)
    avg_preds = np.mean(preds, axis=0)
    acc = np.mean(np.argmax(avg_preds, axis=1) == y_true)
    return acc * 100

tta_acc_new = tta_evaluate(new_model)
print(f"Apple Model TTA Validation Accuracy: {tta_acc_new:.2f}%")

# Save the final model
new_model.save('improved_efficientnet_apple_model.keras')

# Plot training and validation accuracy
train_accuracy = history.history['accuracy'] + history_fine.history['accuracy']
val_accuracy = history.history['val_accuracy'] + history_fine.history['val_accuracy']
epochs = list(range(1, len(train_accuracy) + 1))

plt.figure(figsize=(10, 6))
plt.plot(epochs, [acc * 100 for acc in train_accuracy], label='Training Accuracy', color='#1f77b4')
plt.plot(epochs, [acc * 100 for acc in val_accuracy], label='Validation Accuracy', color='#ff7f0e')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training and Validation Accuracy Over Epochs (Apple Model)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Found subdirectories: ['apple_10-12 days', 'apple_7-9 days', 'apple_1-3 days', 'apple_4-6 days', 'apple_13-15 days']
# Subdirectory apple_10-12 days: 200 images
# Subdirectory apple_7-9 days: 200 images
# Subdirectory apple_1-3 days: 200 images
# Subdirectory apple_4-6 days: 200 images
# Subdirectory apple_13-15 days: 200 images
# Found 800 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Class indices: {'apple_1-3 days': 0, 'apple_10-12 days': 1, 'apple_13-15 days': 2, 'apple_4-6 days': 3, 'apple_7-9 days': 4}
# Number of classes: 5
# Class distribution: {'apple_1-3 days': np.int64(160), 'apple_10-12 days': np.int64(160), 'apple_13-15 days': np.int64(160), 'apple_4-6 days': np.int64(160), 'apple_7-9 days': np.int64(160)}
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27018416/27018416 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 179s 6s/step - accuracy: 0.3822 - loss: 1.9772 - val_accuracy: 0.6350 - val_loss: 1.3588 - learning_rate: 3.0000e-04
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - accuracy: 0.5700 - loss: 1.3553 - val_accuracy: 0.6300 - val_loss: 1.2354 - learning_rate: 3.0000e-04
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 157s 6s/step - accuracy: 0.6374 - loss: 1.2040 - val_accuracy: 0.6600 - val_loss: 1.1539 - learning_rate: 3.0000e-04
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 212s 7s/step - accuracy: 0.6384 - loss: 1.2501 - val_accuracy: 0.6200 - val_loss: 1.1499 - learning_rate: 3.0000e-04
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 188s 6s/step - accuracy: 0.6431 - loss: 1.0468 - val_accuracy: 0.6600 - val_loss: 1.1159 - learning_rate: 3.0000e-04
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - accuracy: 0.6430 - loss: 1.1042 - val_accuracy: 0.6300 - val_loss: 1.1647 - learning_rate: 3.0000e-04
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 167s 7s/step - accuracy: 0.6969 - loss: 0.9640 - val_accuracy: 0.6800 - val_loss: 1.1755 - learning_rate: 3.0000e-04
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 162s 7s/step - accuracy: 0.6545 - loss: 1.0246 - val_accuracy: 0.6700 - val_loss: 0.9799 - learning_rate: 3.0000e-04
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 172s 7s/step - accuracy: 0.6553 - loss: 1.0197 - val_accuracy: 0.6950 - val_loss: 0.9491 - learning_rate: 3.0000e-04
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 194s 7s/step - accuracy: 0.7047 - loss: 0.9143 - val_accuracy: 0.7000 - val_loss: 0.9375 - learning_rate: 3.0000e-04
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 204s 7s/step - accuracy: 0.6995 - loss: 0.9038 - val_accuracy: 0.6950 - val_loss: 0.9443 - learning_rate: 3.0000e-04
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 197s 6s/step - accuracy: 0.6491 - loss: 1.0629 - val_accuracy: 0.6900 - val_loss: 1.0341 - learning_rate: 3.0000e-04
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 194s 6s/step - accuracy: 0.6969 - loss: 0.9418 - val_accuracy: 0.7250 - val_loss: 0.8709 - learning_rate: 3.0000e-04
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 200s 6s/step - accuracy: 0.7004 - loss: 0.8788 - val_accuracy: 0.6900 - val_loss: 0.8120 - learning_rate: 3.0000e-04
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 152s 6s/step - accuracy: 0.6806 - loss: 0.9013 - val_accuracy: 0.7250 - val_loss: 1.0076 - learning_rate: 3.0000e-04
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 160s 6s/step - accuracy: 0.7416 - loss: 0.8903 - val_accuracy: 0.7000 - val_loss: 0.9077 - learning_rate: 3.0000e-04
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 223s 7s/step - accuracy: 0.7329 - loss: 0.8677 - val_accuracy: 0.7300 - val_loss: 0.9907 - learning_rate: 3.0000e-04
# Epoch 18/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 179s 6s/step - accuracy: 0.7090 - loss: 0.9706 - val_accuracy: 0.7100 - val_loss: 0.9974 - learning_rate: 3.0000e-04
# Epoch 19/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 213s 7s/step - accuracy: 0.6924 - loss: 0.9238 - val_accuracy: 0.7400 - val_loss: 1.0234 - learning_rate: 3.0000e-04
# Epoch 20/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 203s 7s/step - accuracy: 0.7666 - loss: 0.7291 - val_accuracy: 0.7200 - val_loss: 1.0222 - learning_rate: 3.0000e-04
# Epoch 21/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 197s 7s/step - accuracy: 0.6956 - loss: 0.8870 - val_accuracy: 0.7350 - val_loss: 1.0092 - learning_rate: 3.0000e-04
# Epoch 22/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 205s 7s/step - accuracy: 0.7262 - loss: 0.8191 - val_accuracy: 0.6750 - val_loss: 1.0042 - learning_rate: 3.0000e-04
# Epoch 23/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 169s 7s/step - accuracy: 0.7885 - loss: 0.7317 - val_accuracy: 0.7350 - val_loss: 0.9730 - learning_rate: 3.0000e-04
# Epoch 24/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 191s 6s/step - accuracy: 0.7313 - loss: 0.7668 - val_accuracy: 0.6800 - val_loss: 1.1495 - learning_rate: 3.0000e-04
# Epoch 25/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 168s 7s/step - accuracy: 0.7303 - loss: 0.8611 - val_accuracy: 0.7300 - val_loss: 1.1099 - learning_rate: 3.0000e-04
# Epoch 26/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 159s 6s/step - accuracy: 0.7256 - loss: 0.7960 - val_accuracy: 0.7250 - val_loss: 1.1006 - learning_rate: 6.0000e-06
# Epoch 27/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 209s 7s/step - accuracy: 0.7069 - loss: 0.8343 - val_accuracy: 0.7250 - val_loss: 1.0948 - learning_rate: 6.0000e-06
# Epoch 28/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 156s 6s/step - accuracy: 0.6968 - loss: 0.8889 - val_accuracy: 0.7300 - val_loss: 1.0869 - learning_rate: 6.0000e-06
# Epoch 29/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 153s 6s/step - accuracy: 0.7107 - loss: 0.8481 - val_accuracy: 0.7250 - val_loss: 1.0838 - learning_rate: 6.0000e-06
# Epoch 30/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 202s 6s/step - accuracy: 0.6849 - loss: 0.9193 - val_accuracy: 0.7100 - val_loss: 1.0811 - learning_rate: 6.0000e-06
# Epoch 31/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 203s 6s/step - accuracy: 0.7060 - loss: 0.8854 - val_accuracy: 0.7100 - val_loss: 1.0825 - learning_rate: 6.0000e-06
# Epoch 32/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 213s 7s/step - accuracy: 0.7565 - loss: 0.7885 - val_accuracy: 0.7100 - val_loss: 1.0815 - learning_rate: 1.2000e-07
# Epoch 33/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 193s 8s/step - accuracy: 0.7245 - loss: 0.7957 - val_accuracy: 0.7100 - val_loss: 1.0774 - learning_rate: 1.2000e-07
# Epoch 34/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 169s 6s/step - accuracy: 0.7156 - loss: 0.7780 - val_accuracy: 0.7100 - val_loss: 1.0733 - learning_rate: 1.2000e-07
# Epoch 35/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 208s 7s/step - accuracy: 0.6913 - loss: 0.8397 - val_accuracy: 0.7100 - val_loss: 1.0760 - learning_rate: 1.2000e-07
# Epoch 36/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 186s 6s/step - accuracy: 0.7217 - loss: 0.8048 - val_accuracy: 0.7100 - val_loss: 1.0710 - learning_rate: 1.2000e-07
# Epoch 37/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 202s 6s/step - accuracy: 0.7416 - loss: 0.7726 - val_accuracy: 0.7100 - val_loss: 1.0699 - learning_rate: 1.2000e-07
# Epoch 38/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 164s 7s/step - accuracy: 0.7446 - loss: 0.8508 - val_accuracy: 0.7100 - val_loss: 1.0688 - learning_rate: 1.0000e-08
# Epoch 39/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 191s 6s/step - accuracy: 0.7338 - loss: 0.8154 - val_accuracy: 0.7100 - val_loss: 1.0689 - learning_rate: 1.0000e-08
# Epoch 40/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 198s 6s/step - accuracy: 0.7373 - loss: 0.7881 - val_accuracy: 0.7100 - val_loss: 1.0681 - learning_rate: 1.0000e-08
# Epoch 41/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 203s 6s/step - accuracy: 0.7168 - loss: 0.8243 - val_accuracy: 0.7050 - val_loss: 1.0686 - learning_rate: 1.0000e-08
# Epoch 42/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 210s 6s/step - accuracy: 0.7511 - loss: 0.7729 - val_accuracy: 0.7100 - val_loss: 1.0641 - learning_rate: 1.0000e-08
# Epoch 43/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 197s 6s/step - accuracy: 0.7841 - loss: 0.7364 - val_accuracy: 0.7100 - val_loss: 1.0607 - learning_rate: 1.0000e-08
# Epoch 44/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 205s 6s/step - accuracy: 0.7256 - loss: 0.8344 - val_accuracy: 0.7100 - val_loss: 1.0654 - learning_rate: 1.0000e-08
# Epoch 45/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 200s 6s/step - accuracy: 0.7563 - loss: 0.7725 - val_accuracy: 0.7100 - val_loss: 1.0673 - learning_rate: 1.0000e-08
# Epoch 46/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 202s 6s/step - accuracy: 0.7602 - loss: 0.8102 - val_accuracy: 0.7100 - val_loss: 1.0669 - learning_rate: 1.0000e-08
# Epoch 47/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 216s 7s/step - accuracy: 0.7137 - loss: 0.8110 - val_accuracy: 0.7100 - val_loss: 1.0660 - learning_rate: 1.0000e-08
# Epoch 48/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 189s 6s/step - accuracy: 0.6991 - loss: 0.8423 - val_accuracy: 0.7100 - val_loss: 1.0678 - learning_rate: 1.0000e-08
# Epoch 49/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 213s 7s/step - accuracy: 0.7360 - loss: 0.7923 - val_accuracy: 0.7100 - val_loss: 1.0712 - learning_rate: 1.0000e-08
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 278s 9s/step - accuracy: 0.5863 - loss: 1.2259 - val_accuracy: 0.7300 - val_loss: 0.9982 - learning_rate: 5.0000e-07
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 219s 9s/step - accuracy: 0.6136 - loss: 1.1169 - val_accuracy: 0.7350 - val_loss: 0.9880 - learning_rate: 5.0000e-07
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 258s 9s/step - accuracy: 0.5877 - loss: 1.1904 - val_accuracy: 0.7150 - val_loss: 0.9859 - learning_rate: 5.0000e-07
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 261s 9s/step - accuracy: 0.6096 - loss: 1.1891 - val_accuracy: 0.7250 - val_loss: 0.9814 - learning_rate: 5.0000e-07
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 255s 8s/step - accuracy: 0.5984 - loss: 1.1494 - val_accuracy: 0.7150 - val_loss: 0.9846 - learning_rate: 5.0000e-07
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 207s 8s/step - accuracy: 0.5455 - loss: 1.2619 - val_accuracy: 0.7000 - val_loss: 0.9822 - learning_rate: 5.0000e-07
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 219s 9s/step - accuracy: 0.5899 - loss: 1.2194 - val_accuracy: 0.7000 - val_loss: 0.9754 - learning_rate: 5.0000e-07
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 262s 9s/step - accuracy: 0.6188 - loss: 1.1568 - val_accuracy: 0.6950 - val_loss: 0.9620 - learning_rate: 5.0000e-07
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 203s 8s/step - accuracy: 0.6005 - loss: 1.1918 - val_accuracy: 0.6900 - val_loss: 0.9544 - learning_rate: 1.0000e-08
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 268s 8s/step - accuracy: 0.5869 - loss: 1.1951 - val_accuracy: 0.6900 - val_loss: 0.9491 - learning_rate: 1.0000e-08
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 255s 8s/step - accuracy: 0.5547 - loss: 1.2559 - val_accuracy: 0.6900 - val_loss: 0.9455 - learning_rate: 1.0000e-08
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 217s 9s/step - accuracy: 0.6242 - loss: 1.0909 - val_accuracy: 0.6900 - val_loss: 0.9384 - learning_rate: 1.0000e-08
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 260s 9s/step - accuracy: 0.6237 - loss: 1.1505 - val_accuracy: 0.6950 - val_loss: 0.9366 - learning_rate: 1.0000e-08
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 213s 9s/step - accuracy: 0.6479 - loss: 1.1366 - val_accuracy: 0.6900 - val_loss: 0.9344 - learning_rate: 1.0000e-08
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 253s 8s/step - accuracy: 0.6011 - loss: 1.1815 - val_accuracy: 0.6900 - val_loss: 0.9365 - learning_rate: 1.0000e-08
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 204s 8s/step - accuracy: 0.6205 - loss: 1.1415 - val_accuracy: 0.6900 - val_loss: 0.9325 - learning_rate: 1.0000e-08
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 200s 8s/step - accuracy: 0.6259 - loss: 1.1917 - val_accuracy: 0.6900 - val_loss: 0.9326 - learning_rate: 1.0000e-08
# Epoch 18/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 202s 8s/step - accuracy: 0.5939 - loss: 1.2620 - val_accuracy: 0.6900 - val_loss: 0.9318 - learning_rate: 1.0000e-08
# Epoch 19/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 217s 9s/step - accuracy: 0.5916 - loss: 1.2327 - val_accuracy: 0.6900 - val_loss: 0.9272 - learning_rate: 1.0000e-08
# Epoch 20/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 247s 8s/step - accuracy: 0.6150 - loss: 1.1141 - val_accuracy: 0.6850 - val_loss: 0.9279 - learning_rate: 1.0000e-08
# Epoch 21/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 273s 9s/step - accuracy: 0.6074 - loss: 1.1857 - val_accuracy: 0.6850 - val_loss: 0.9319 - learning_rate: 1.0000e-08
# Epoch 22/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 257s 8s/step - accuracy: 0.6149 - loss: 1.1002 - val_accuracy: 0.6800 - val_loss: 0.9318 - learning_rate: 1.0000e-08
# Epoch 23/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 205s 8s/step - accuracy: 0.6061 - loss: 1.1739 - val_accuracy: 0.6850 - val_loss: 0.9322 - learning_rate: 1.0000e-08
# Epoch 24/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 206s 8s/step - accuracy: 0.6048 - loss: 1.1314 - val_accuracy: 0.6800 - val_loss: 0.9348 - learning_rate: 1.0000e-08
# Epoch 25/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 205s 8s/step - accuracy: 0.6219 - loss: 1.1537 - val_accuracy: 0.6950 - val_loss: 0.9295 - learning_rate: 1.0000e-08
# Epoch 26/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 258s 8s/step - accuracy: 0.6110 - loss: 1.0818 - val_accuracy: 0.6900 - val_loss: 0.9260 - learning_rate: 1.0000e-08
# Epoch 27/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 201s 8s/step - accuracy: 0.6088 - loss: 1.1588 - val_accuracy: 0.6850 - val_loss: 0.9349 - learning_rate: 1.0000e-08
# Epoch 28/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 202s 8s/step - accuracy: 0.6227 - loss: 1.1631 - val_accuracy: 0.6850 - val_loss: 0.9307 - learning_rate: 1.0000e-08
# Epoch 29/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 215s 9s/step - accuracy: 0.6196 - loss: 1.1176 - val_accuracy: 0.6800 - val_loss: 0.9314 - learning_rate: 1.0000e-08
# Epoch 30/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 203s 8s/step - accuracy: 0.5888 - loss: 1.1805 - val_accuracy: 0.6900 - val_loss: 0.9294 - learning_rate: 1.0000e-08
# Epoch 31/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 214s 9s/step - accuracy: 0.5533 - loss: 1.2369 - val_accuracy: 0.6900 - val_loss: 0.9303 - learning_rate: 1.0000e-08
# Epoch 32/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 263s 9s/step - accuracy: 0.6150 - loss: 1.2211 - val_accuracy: 0.6850 - val_loss: 0.9333 - learning_rate: 1.0000e-08
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 28s 4s/step - accuracy: 0.7794 - loss: 0.7865
# Apple Model Validation Accuracy: 73.50%
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Apple Model TTA Validation Accuracy: 75.00%

# %%
# Load and evaluate the model
model = tf.keras.models.load_model('best_efficientnet_apple_model.keras')
val_loss, val_acc = model.evaluate(val_generator)
print(f"Apple Model Validation Accuracy: {val_acc * 100:.2f}%")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.7805 - loss: 0.8928
# Apple Model Validation Accuracy: 72.00%
