jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/bp310.jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/bp311.jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/bp312.jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/bp50.jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/bp51.jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/bp52.jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/bp54.jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/bp55.jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/bp56.jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/bp57.jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (13).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (133).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (134).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (135).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (136).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (137).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (14).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (15).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (159).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (16).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (17).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (18).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (19).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (20).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (208).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (209).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (213).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (214).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (215).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (216).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (217).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (218).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (221).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (222).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (224).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/c (225).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (100).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (103).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (107).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (113).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (122).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (124).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (125).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (137).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (260).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (281).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (34).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (37).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (420).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (50).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (508).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (54).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (593).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (61).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (88).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/freshPepper (94).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/IMG_20220530_085235.jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/IMG_20220530_085237.jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (1).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (10).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (100).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (11).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (12).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (13).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (14).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (15).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (16).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (17).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (18).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (19).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (2).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (20).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (21).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (22).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (23).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (24).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (25).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (26).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (27).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (28).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (29).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (3).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (30).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (31).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (32).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (33).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (34).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (35).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (36).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (37).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (38).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (39).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (4).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (40).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (41).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (42).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (43).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (44).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (45).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (46).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (47).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (48).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (49).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (5).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (50).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (51).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (52).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (53).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (54).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (55).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (56).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (57).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (58).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (59).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (6).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (60).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (61).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (62).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (63).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (64).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (65).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (66).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (67).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (68).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (69).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (7).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (70).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (71).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (72).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (73).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (74).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (75).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (76).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (77).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (78).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (79).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (8).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (80).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (81).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (82).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (83).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (84).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (85).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (86).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (87).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (88).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (89).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (9).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (90).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (91).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (92).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (93).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (94).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (95).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (96).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (97).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (98).jpg
#   inflating: /content/datasets/bell/bell_dataset/6-7 days/six days (99).jpg

# %%
import os
import shutil

base_dir = '/content/datasets'
combined_dir = '/content/combined_dataset'
os.makedirs(combined_dir, exist_ok=True)

foods = [ 'bell']

food_stages = {

    'bell': ['1-2 days', '3 days', '4 days', '5 days', '6-7 days'],

}

for food in foods:
    food_path = os.path.join(base_dir, food)
    if os.path.exists(food_path):
        nested_folder = None
        for item in os.listdir(food_path):
            full_path = os.path.join(food_path, item)
            if os.path.isdir(full_path) and item.lower() == f"{food}_dataset".lower():
                nested_folder = full_path
                break
        if nested_folder:
            actual_stages = [d for d in os.listdir(nested_folder) if os.path.isdir(os.path.join(nested_folder, d))]
        else:
            actual_stages = [d for d in os.listdir(food_path) if os.path.isdir(os.path.join(food_path, d))]
        print(f"Checking {food}: Nested folder? {nested_folder}, Expected stages: {food_stages[food]}, Actual stages: {actual_stages}")
        for stage in food_stages[food]:
            src = os.path.join(nested_folder if nested_folder else food_path, stage)
            if os.path.exists(src):
                dst_class = f"{food}_{stage}"
                dst = os.path.join(combined_dir, dst_class)
                os.makedirs(dst, exist_ok=True)
                for img in os.listdir(src):
                    if os.path.isfile(os.path.join(src, img)):
                        shutil.copy(os.path.join(src, img), os.path.join(dst, img))
            else:
                print(f"Warning: {src} not found for {food}")

print("Combined dataset classes:", os.listdir(combined_dir))
# Out:
# Checking bell: Nested folder? /content/datasets/bell/bell_dataset, Expected stages: ['1-2 days', '3 days', '4 days', '5 days', '6-7 days'], Actual stages: ['5 days', '1-2 days', '4 days', '3 days', '6-7 days']
# Combined dataset classes: ['bell_6-7 days', 'bell_3 days', 'bell_4 days', 'bell_5 days', 'bell_1-2 days']

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import class_weight
import random
import os

# Custom Cutout augmentation
def cutout(image):
    if random.random() < 0.5:  # Apply Cutout with 50% probability
        h, w = image.shape[:2]
        cutout_size = random.randint(20, 70)  # Increased size range for bell peppers
        x = random.randint(0, w - cutout_size)
        y = random.randint(0, h - cutout_size)
        image[y:y+cutout_size, x:x+cutout_size, :] = 0
    return image

# Combined preprocessing function for EfficientNetB0 and Cutout
def preprocess_with_cutout(x):
    x = tf.keras.applications.efficientnet.preprocess_input(x)
    x = cutout(x)
    return x

# Step 1: Set up data generators with enhanced augmentation for bell dataset
datagen_aug = ImageDataGenerator(
    preprocessing_function=preprocess_with_cutout,
    validation_split=0.2,
    rotation_range=80,  # Increased for more diversity
    width_shift_range=0.5,
    height_shift_range=0.5,
    shear_range=0.5,
    zoom_range=[0.2, 1.8],  # Wider zoom range
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest',
    brightness_range=[0.3, 1.7],  # Wider brightness
    channel_shift_range=40.0  # Increased for stronger color jittering
)

datagen_no_aug = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    validation_split=0.2
)

# Ensure dataset directory exists
data_dir = '/content/combined_dataset'
if not os.path.exists(data_dir):
    raise FileNotFoundError(f"Dataset directory {data_dir} not found. Please update the path or ensure the dataset exists.")

# Check dataset structure
subdirs = [d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
print(f"Found subdirectories: {subdirs}")
if len(subdirs) != 5:
    print(f"Warning: Expected 5 subdirectories, found {len(subdirs)}. Please check dataset structure.")

# Count images in each subdirectory
for subdir in subdirs:
    subdir_path = os.path.join(data_dir, subdir)
    image_files = [f for f in os.listdir(subdir_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    print(f"Subdirectory {subdir}: {len(image_files)} images")

train_generator = datagen_aug.flow_from_directory(
    data_dir,
    target_size=(256, 256),  # Increased resolution
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

val_generator = datagen_no_aug.flow_from_directory(
    data_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Verify class indices and check for balance
print("Class indices:", train_generator.class_indices)
print("Number of classes:", len(train_generator.class_indices))
class_counts = np.bincount(train_generator.classes)
print("Class distribution:", dict(zip(train_generator.class_indices.keys(), class_counts)))

# Compute class weights for potential imbalance
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights_dict = dict(enumerate(class_weights))

# Step 2: Build EfficientNetB0 model optimized for 5-class bell classification
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(256, 256, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.00002))(x)
x = BatchNormalization()(x)
x = Dropout(0.15)(x)  # Reduced dropout
x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.00002))(x)
x = BatchNormalization()(x)
x = Dropout(0.15)(x)
predictions = Dense(5, activation='softmax')(x)  # 5 classes for bell stages

new_model = Model(inputs=base_model.input, outputs=predictions)

# Freeze base layers initially
for layer in base_model.layers:
    layer.trainable = False

new_model.compile(optimizer=AdamW(learning_rate=0.0005, weight_decay=0.0001),  # Lower initial LR
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# Callbacks
early_stop = EarlyStopping(monitor='val_accuracy', patience=30, restore_best_weights=True, mode='max')  # Increased patience
lr_reduce = ReduceLROnPlateau(monitor='val_accuracy', factor=0.02, patience=6, min_lr=1e-8, mode='max')
checkpoint = ModelCheckpoint('best_efficientnet_bell_model.keras', monitor='val_accuracy', save_best_only=True, mode='max')

# Train initial phase
history = new_model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=val_generator,
    validation_steps=len(val_generator),
    callbacks=[early_stop, lr_reduce, checkpoint],
    class_weight=class_weights_dict
)

# Fine-tune more layers (EfficientNetB0 has ~237 layers)
for layer in base_model.layers[-140:]:  # Increased to 140 layers
    layer.trainable = True

new_model.compile(optimizer=AdamW(learning_rate=0.000001, weight_decay=0.00001),  # Very low LR for fine-tuning
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# Fine-tune
history_fine = new_model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=val_generator,
    validation_steps=len(val_generator),
    callbacks=[early_stop, lr_reduce, checkpoint],
    class_weight=class_weights_dict
)

# Evaluate
val_loss_new, val_acc_new = new_model.evaluate(val_generator)
print(f"Bell Model Validation Accuracy: {val_acc_new * 100:.2f}%")

# Enhanced Test-Time Augmentation (TTA)
def tta_evaluate(model, num_augs=50):
    tta_datagen = ImageDataGenerator(
        preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
        rotation_range=50,
        width_shift_range=0.4,
        height_shift_range=0.4,
        shear_range=0.4,
        zoom_range=0.4,
        horizontal_flip=True,
        fill_mode='nearest',
        validation_split=0.2
    )
    preds = []
    y_true = val_generator.classes
    for i in range(num_augs):
        tta_gen = tta_datagen.flow_from_directory(
            data_dir,
            target_size=(256, 256),
            batch_size=32,
            class_mode='categorical',
            subset='validation',
            shuffle=False,
            seed=42 + i
        )
        batch_preds = model.predict(tta_gen, steps=len(tta_gen), verbose=0)
        preds.append(batch_preds)
    avg_preds = np.mean(preds, axis=0)
    acc = np.mean(np.argmax(avg_preds, axis=1) == y_true)
    return acc * 100

tta_acc_new = tta_evaluate(new_model)
print(f"Bell Model TTA Validation Accuracy: {tta_acc_new:.2f}%")

# Save the final model
new_model.save('improved_efficientnet_bell_model.keras')

# Plot training and validation accuracy
train_accuracy = history.history['accuracy'] + history_fine.history['accuracy']
val_accuracy = history.history['val_accuracy'] + history_fine.history['val_accuracy']
epochs = list(range(1, len(train_accuracy) + 1))

plt.figure(figsize=(10, 6))
plt.plot(epochs, [acc * 100 for acc in train_accuracy], label='Training Accuracy', color='#1f77b4')
plt.plot(epochs, [acc * 100 for acc in val_accuracy], label='Validation Accuracy', color='#ff7f0e')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training and Validation Accuracy Over Epochs (Bell Model)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Found subdirectories: ['bell_6-7 days', 'bell_3 days', 'bell_4 days', 'bell_5 days', 'bell_1-2 days']
# Subdirectory bell_6-7 days: 200 images
# Subdirectory bell_3 days: 200 images
# Subdirectory bell_4 days: 200 images
# Subdirectory bell_5 days: 200 images
# Subdirectory bell_1-2 days: 200 images
# Found 800 images belonging to 5 classes.
# Found 200 images belonging to 5 classes.
# Class indices: {'bell_1-2 days': 0, 'bell_3 days': 1, 'bell_4 days': 2, 'bell_5 days': 3, 'bell_6-7 days': 4}
# Number of classes: 5
# Class distribution: {'bell_1-2 days': np.int64(160), 'bell_3 days': np.int64(160), 'bell_4 days': np.int64(160), 'bell_5 days': np.int64(160), 'bell_6-7 days': np.int64(160)}
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 135s 5s/step - accuracy: 0.5414 - loss: 1.4661 - val_accuracy: 0.9250 - val_loss: 0.4669 - learning_rate: 5.0000e-04
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 133s 4s/step - accuracy: 0.8311 - loss: 0.6825 - val_accuracy: 0.8950 - val_loss: 0.4487 - learning_rate: 5.0000e-04
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 114s 5s/step - accuracy: 0.8256 - loss: 0.6077 - val_accuracy: 0.9300 - val_loss: 0.3224 - learning_rate: 5.0000e-04
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 144s 5s/step - accuracy: 0.8707 - loss: 0.4132 - val_accuracy: 0.8800 - val_loss: 0.4241 - learning_rate: 5.0000e-04
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 113s 5s/step - accuracy: 0.8396 - loss: 0.5213 - val_accuracy: 0.8850 - val_loss: 0.3718 - learning_rate: 5.0000e-04
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.8413 - loss: 0.5616 - val_accuracy: 0.8700 - val_loss: 0.4111 - learning_rate: 5.0000e-04
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 139s 4s/step - accuracy: 0.8357 - loss: 0.5182 - val_accuracy: 0.8750 - val_loss: 0.3710 - learning_rate: 5.0000e-04
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 127s 4s/step - accuracy: 0.8619 - loss: 0.4772 - val_accuracy: 0.8800 - val_loss: 0.3490 - learning_rate: 5.0000e-04
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 114s 5s/step - accuracy: 0.8809 - loss: 0.3780 - val_accuracy: 0.9450 - val_loss: 0.2159 - learning_rate: 5.0000e-04
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 121s 4s/step - accuracy: 0.8664 - loss: 0.4172 - val_accuracy: 0.9450 - val_loss: 0.2077 - learning_rate: 5.0000e-04
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 150s 4s/step - accuracy: 0.8624 - loss: 0.4019 - val_accuracy: 0.9050 - val_loss: 0.3057 - learning_rate: 5.0000e-04
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8570 - loss: 0.4569 - val_accuracy: 0.9400 - val_loss: 0.2207 - learning_rate: 5.0000e-04
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - accuracy: 0.8809 - loss: 0.4166 - val_accuracy: 0.9500 - val_loss: 0.2047 - learning_rate: 5.0000e-04
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 101s 4s/step - accuracy: 0.8783 - loss: 0.4058 - val_accuracy: 0.9500 - val_loss: 0.1927 - learning_rate: 5.0000e-04
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 137s 4s/step - accuracy: 0.9074 - loss: 0.3356 - val_accuracy: 0.9000 - val_loss: 0.3227 - learning_rate: 5.0000e-04
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.9004 - loss: 0.3478 - val_accuracy: 0.8550 - val_loss: 0.5114 - learning_rate: 5.0000e-04
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8978 - loss: 0.3508 - val_accuracy: 0.9600 - val_loss: 0.1605 - learning_rate: 5.0000e-04
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - accuracy: 0.8854 - loss: 0.3541 - val_accuracy: 0.9200 - val_loss: 0.2762 - learning_rate: 5.0000e-04
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 151s 4s/step - accuracy: 0.8904 - loss: 0.3519 - val_accuracy: 0.8500 - val_loss: 0.5620 - learning_rate: 5.0000e-04
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 137s 4s/step - accuracy: 0.8991 - loss: 0.3214 - val_accuracy: 0.9350 - val_loss: 0.2559 - learning_rate: 5.0000e-04
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - accuracy: 0.8737 - loss: 0.3523 - val_accuracy: 0.9050 - val_loss: 0.3571 - learning_rate: 5.0000e-04
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 145s 4s/step - accuracy: 0.8785 - loss: 0.3246 - val_accuracy: 0.9500 - val_loss: 0.2066 - learning_rate: 5.0000e-04
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 101s 4s/step - accuracy: 0.9028 - loss: 0.3137 - val_accuracy: 0.9500 - val_loss: 0.1964 - learning_rate: 5.0000e-04
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 105s 4s/step - accuracy: 0.9118 - loss: 0.2900 - val_accuracy: 0.9550 - val_loss: 0.1959 - learning_rate: 1.0000e-05
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 134s 4s/step - accuracy: 0.8776 - loss: 0.3315 - val_accuracy: 0.9550 - val_loss: 0.1986 - learning_rate: 1.0000e-05
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 0.9277 - loss: 0.2765 - val_accuracy: 0.9550 - val_loss: 0.1998 - learning_rate: 1.0000e-05
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 0.8918 - loss: 0.3011 - val_accuracy: 0.9550 - val_loss: 0.2060 - learning_rate: 1.0000e-05
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 0.8834 - loss: 0.3707 - val_accuracy: 0.9550 - val_loss: 0.2082 - learning_rate: 1.0000e-05
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 110s 4s/step - accuracy: 0.8778 - loss: 0.3858 - val_accuracy: 0.9550 - val_loss: 0.2070 - learning_rate: 1.0000e-05
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - accuracy: 0.8893 - loss: 0.3631 - val_accuracy: 0.9550 - val_loss: 0.2078 - learning_rate: 2.0000e-07
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - accuracy: 0.9036 - loss: 0.3135 - val_accuracy: 0.9550 - val_loss: 0.2073 - learning_rate: 2.0000e-07
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 101s 4s/step - accuracy: 0.9014 - loss: 0.3358 - val_accuracy: 0.9550 - val_loss: 0.2070 - learning_rate: 2.0000e-07
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 143s 4s/step - accuracy: 0.9110 - loss: 0.2778 - val_accuracy: 0.9550 - val_loss: 0.2074 - learning_rate: 2.0000e-07
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 148s 4s/step - accuracy: 0.9067 - loss: 0.3131 - val_accuracy: 0.9550 - val_loss: 0.2078 - learning_rate: 2.0000e-07
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 131s 4s/step - accuracy: 0.9046 - loss: 0.3008 - val_accuracy: 0.9550 - val_loss: 0.2088 - learning_rate: 2.0000e-07
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - accuracy: 0.9160 - loss: 0.2903 - val_accuracy: 0.9550 - val_loss: 0.2084 - learning_rate: 1.0000e-08
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - accuracy: 0.8987 - loss: 0.2980 - val_accuracy: 0.9550 - val_loss: 0.2093 - learning_rate: 1.0000e-08
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.8997 - loss: 0.3622 - val_accuracy: 0.9550 - val_loss: 0.2080 - learning_rate: 1.0000e-08
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 151s 4s/step - accuracy: 0.8895 - loss: 0.3213 - val_accuracy: 0.9550 - val_loss: 0.2046 - learning_rate: 1.0000e-08
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - accuracy: 0.9199 - loss: 0.2632 - val_accuracy: 0.9550 - val_loss: 0.2036 - learning_rate: 1.0000e-08
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 0.8935 - loss: 0.3219 - val_accuracy: 0.9550 - val_loss: 0.2029 - learning_rate: 1.0000e-08
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 0.8959 - loss: 0.3355 - val_accuracy: 0.9550 - val_loss: 0.2044 - learning_rate: 1.0000e-08
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 0.8924 - loss: 0.3317 - val_accuracy: 0.9550 - val_loss: 0.2042 - learning_rate: 1.0000e-08
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 141s 4s/step - accuracy: 0.8907 - loss: 0.3371 - val_accuracy: 0.9550 - val_loss: 0.2063 - learning_rate: 1.0000e-08
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 143s 4s/step - accuracy: 0.8716 - loss: 0.4145 - val_accuracy: 0.9550 - val_loss: 0.2049 - learning_rate: 1.0000e-08
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - accuracy: 0.8989 - loss: 0.3108 - val_accuracy: 0.9550 - val_loss: 0.2049 - learning_rate: 1.0000e-08
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 141s 4s/step - accuracy: 0.8955 - loss: 0.3204 - val_accuracy: 0.9550 - val_loss: 0.2052 - learning_rate: 1.0000e-08
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 201s 7s/step - accuracy: 0.7343 - loss: 0.8900 - val_accuracy: 0.9450 - val_loss: 0.2121 - learning_rate: 1.0000e-06
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 191s 6s/step - accuracy: 0.7679 - loss: 0.8008 - val_accuracy: 0.9150 - val_loss: 0.2779 - learning_rate: 1.0000e-06
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 159s 6s/step - accuracy: 0.7565 - loss: 0.6917 - val_accuracy: 0.9050 - val_loss: 0.3401 - learning_rate: 1.0000e-06
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 196s 6s/step - accuracy: 0.7339 - loss: 0.8739 - val_accuracy: 0.8900 - val_loss: 0.3924 - learning_rate: 1.0000e-06
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 202s 6s/step - accuracy: 0.7786 - loss: 0.6955 - val_accuracy: 0.8750 - val_loss: 0.4359 - learning_rate: 1.0000e-06
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 158s 6s/step - accuracy: 0.7514 - loss: 0.7469 - val_accuracy: 0.8500 - val_loss: 0.4686 - learning_rate: 1.0000e-06
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 197s 6s/step - accuracy: 0.7759 - loss: 0.7465 - val_accuracy: 0.8300 - val_loss: 0.4945 - learning_rate: 1.0000e-06
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 225s 7s/step - accuracy: 0.7678 - loss: 0.7570 - val_accuracy: 0.8200 - val_loss: 0.5183 - learning_rate: 2.0000e-08
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 185s 7s/step - accuracy: 0.7181 - loss: 0.8879 - val_accuracy: 0.8200 - val_loss: 0.5428 - learning_rate: 2.0000e-08
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 187s 7s/step - accuracy: 0.7581 - loss: 0.7885 - val_accuracy: 0.8100 - val_loss: 0.5673 - learning_rate: 2.0000e-08
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━